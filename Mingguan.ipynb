# %%
from zipfile import ZipFile
import pandas as pd
import os

# 1. Deklarasi nama file ZIP
zip_file_name = "Mingguan.zip"

# 2. Ekstrak file ZIP ke folder 'csv_folder'
with ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall("csv_folder")

# 3. Baca dan tampilkan file di dalamnya
folder_path = "csv_folder"
for i in range(1, 22):
    file_path = os.path.join(folder_path, f"{i}.csv")
    if os.path.exists(file_path):
        print(f"\n--- Isi dari {i}.csv ---")
        df = pd.read_csv(file_path)
        display(df)
    else:
        print(f"File {i}.csv tidak ditemukan.")
# Out:
# --- Isi dari 1.csv ---
#                         Date     HLAG.DE   HLAG.DE.1   HLAG.DE.2   HLAG.DE.3  \
# 0    2015-11-02T00:00:00.000   11.799647   11.910580   11.677038   11.706232
# 1    2015-11-09T00:00:00.000   11.618655   12.056544   11.516481   11.881388
# 2    2015-11-16T00:00:00.000   11.706231   11.793808   11.385112   11.571944
# 3    2015-11-23T00:00:00.000   11.779213   12.961513   11.350081   11.677038
# 4    2015-11-30T00:00:00.000   11.852196   12.147041   11.297536   11.618655
# ..                       ...         ...         ...         ...         ...
# 495  2025-04-28T00:00:00.000  124.991577  132.515525  122.828454  131.857182
# 496  2025-05-05T00:00:00.000  129.699997  137.300003  124.500000  133.600006
# 497  2025-05-12T00:00:00.000  167.000000  171.800003  132.000000  132.000000
# 498  2025-05-19T00:00:00.000  159.100006  166.899994  156.000000  166.899994
# 499  2025-05-26T00:00:00.000  144.399994  160.899994  143.899994  160.000000
#
#      HLAG.DE.4
# ...
