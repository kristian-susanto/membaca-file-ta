# %%
from zipfile import ZipFile
import pandas as pd
import os

# 1. Deklarasi nama file ZIP
zip_file_name = "Harian.zip"

# 2. Ekstrak file ZIP ke folder 'csv_folder'
with ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall("csv_folder")

# 3. Baca dan tampilkan file di dalamnya
folder_path = "csv_folder"
for i in range(1, 22):
    file_path = os.path.join(folder_path, f"{i}.csv")
    if os.path.exists(file_path):
        print(f"\n--- Isi dari {i}.csv ---")
        df = pd.read_csv(file_path)
        display(df)
    else:
        print(f"File {i}.csv tidak ditemukan.")
# Out:
# --- Isi dari 1.csv ---
#                          Date     HLAG.DE   HLAG.DE.1   HLAG.DE.2   HLAG.DE.3  \
# 0     2015-11-06T00:00:00.000   11.799647   11.910580   11.677038   11.706232
# 1     2015-11-09T00:00:00.000   11.758779   11.881386   11.720827   11.881386
# 2     2015-11-10T00:00:00.000   11.700393   11.945611   11.677038   11.764616
# 3     2015-11-11T00:00:00.000   11.647846   12.056542   11.516479   11.735424
# 4     2015-11-12T00:00:00.000   11.677038   11.779213   11.618654   11.624491
# ...                       ...         ...         ...         ...         ...
# 2425  2025-05-26T00:00:00.000  155.800003  160.899994  154.800003  160.000000
# 2426  2025-05-27T00:00:00.000  154.300003  156.199997  153.500000  154.500000
# 2427  2025-05-28T00:00:00.000  146.500000  154.300003  145.100006  154.000000
# 2428  2025-05-29T00:00:00.000  146.600006  150.000000  145.699997  149.600006
# 2429  2025-05-30T00:00:00.000  144.399994  148.800003  143.899994  145.500000
#
#       HLAG.DE.4
# 0       1775788
# 1         52918
# 2        236784
# 3       1004556
# 4         56239
# ...         ...
# 2425      12297
# 2426      10366
# 2427      19145
# 2428      16958
# 2429      12093
#
# [2430 rows x 6 columns]
# --- Isi dari 2.csv ---
#    Unnamed: 0          Column Non-Null Count    Dtype
# 0           0   Close,HLAG.DE  2430 non-null  float64
# 1           1    High,HLAG.DE  2430 non-null  float64
# 2           2     Low,HLAG.DE  2430 non-null  float64
# 3           3    Open,HLAG.DE  2430 non-null  float64
# 4           4  Volume,HLAG.DE  2430 non-null    int64
# --- Isi dari 3.csv ---
#                       Date      Close       High        Low       Open  \
# 0  2015-11-06T00:00:00.000  11.799647  11.910580  11.677038  11.706232
# 1  2015-11-09T00:00:00.000  11.758779  11.881386  11.720827  11.881386
# 2  2015-11-10T00:00:00.000  11.700393  11.945611  11.677038  11.764616
# 3  2015-11-11T00:00:00.000  11.647846  12.056542  11.516479  11.735424
# 4  2015-11-12T00:00:00.000  11.677038  11.779213  11.618654  11.624491
#
#     Volume
# 0  1775788
# 1    52918
# 2   236784
# 3  1004556
# 4    56239
# --- Isi dari 4.csv ---
#    Unnamed: 0                     Date      Close       High        Low  \
# 0           0  2015-11-06T00:00:00.000  11.799647  11.910580  11.677038
# 1           1  2015-11-09T00:00:00.000  11.758779  11.881386  11.720827
# 2           2  2015-11-10T00:00:00.000  11.700393  11.945611  11.677038
# 3           3  2015-11-11T00:00:00.000  11.647846  12.056542  11.516479
# 4           4  2015-11-12T00:00:00.000  11.677038  11.779213  11.618654
#
#         Open   Volume
# 0  11.706232  1775788
# 1  11.881386    52918
# 2  11.764616   236784
# 3  11.735424  1004556
# 4  11.624491    56239
# --- Isi dari 5.csv ---
#       Unnamed: 0                     Date   Close
# 0              0  2015-11-06T00:00:00.000   11.80
# 1              1  2015-11-09T00:00:00.000   11.76
# 2              2  2015-11-10T00:00:00.000   11.70
# 3              3  2015-11-11T00:00:00.000   11.65
# 4              4  2015-11-12T00:00:00.000   11.68
# ...          ...                      ...     ...
# 2425        2425  2025-05-26T00:00:00.000  155.80
# 2426        2426  2025-05-27T00:00:00.000  154.30
# 2427        2427  2025-05-28T00:00:00.000  146.50
# 2428        2428  2025-05-29T00:00:00.000  146.60
# 2429        2429  2025-05-30T00:00:00.000  144.40
#
# [2430 rows x 3 columns]
# --- Isi dari 6.csv ---
#    Unnamed: 0 Column Non-Null Count           Dtype
# 0           0   Date  2430 non-null  datetime64[ns]
# 1           1  Close  2430 non-null         float64
# --- Isi dari 7.csv ---
#    Unnamed: 0 Feature  Missing Values               Keterangan
# 0           0   Close               0  Tidak ada missing value
# --- Isi dari 8.csv ---
#    Unnamed: 0 Feature  Negative Values               Keterangan
# 0           0   Close                0  Tidak ada nilai negatif
# --- Isi dari 9.csv ---
#   Unnamed: 0        Close
# 0      count  2430.000000
# 1       mean    79.556498
# 2        std    67.072228
# 3        min     8.700000
# 4        25%    18.615000
# 5        50%    45.450000
# 6        75%   137.690000
# 7        max   285.650000
# --- Isi dari 10.csv ---
#       Unnamed: 0                  Tanggal  Close yang Diskalasikan
# 0              0  2015-11-06T00:00:00.000                 0.011193
# 1              1  2015-11-09T00:00:00.000                 0.011049
# 2              2  2015-11-10T00:00:00.000                 0.010832
# 3              3  2015-11-11T00:00:00.000                 0.010652
# 4              4  2015-11-12T00:00:00.000                 0.010760
# ...          ...                      ...                      ...
# 2425        2425  2025-05-26T00:00:00.000                 0.531143
# 2426        2426  2025-05-27T00:00:00.000                 0.525727
# 2427        2427  2025-05-28T00:00:00.000                 0.497563
# 2428        2428  2025-05-29T00:00:00.000                 0.497924
# 2429        2429  2025-05-30T00:00:00.000                 0.489980
#
# [2430 rows x 3 columns]
# --- Isi dari 11.csv ---
#       Unnamed: 0                                       X (sequence)  \
# 0              0  0.0112,0.011,0.0108,0.0107,0.0108,0.0105,0.010...
# 1              1  0.011,0.0108,0.0107,0.0108,0.0105,0.0104,0.010...
# 2              2  0.0108,0.0107,0.0108,0.0105,0.0104,0.0109,0.01...
# 3              3  0.0107,0.0108,0.0105,0.0104,0.0109,0.0108,0.01...
# 4              4  0.0108,0.0105,0.0104,0.0109,0.0108,0.0102,0.01...
# ...          ...                                                ...
# 2365        2365  0.4773,0.4749,0.4698,0.4746,0.4593,0.4651,0.46...
# 2366        2366  0.4749,0.4698,0.4746,0.4593,0.4651,0.4681,0.46...
# 2367        2367  0.4698,0.4746,0.4593,0.4651,0.4681,0.4644,0.49...
# 2368        2368  0.4746,0.4593,0.4651,0.4681,0.4644,0.4963,0.46...
# 2369        2369  0.4593,0.4651,0.4681,0.4644,0.4963,0.4613,0.46...
#
#       y (target)
# 0         0.0034
# 1         0.0042
# 2         0.0034
# 3         0.0015
# 4         0.0000
# ...          ...
# 2365      0.5311
# 2366      0.5257
# 2367      0.4976
# 2368      0.4979
# 2369      0.4900
#
# [2370 rows x 3 columns]
# --- Isi dari 12.csv ---
#       Unnamed: 0                                 X_train (sequence)  y_train
# 0              0  0.0112,0.011,0.0108,0.0107,0.0108,0.0105,0.010...   0.0034
# 1              1  0.011,0.0108,0.0107,0.0108,0.0105,0.0104,0.010...   0.0042
# 2              2  0.0108,0.0107,0.0108,0.0105,0.0104,0.0109,0.01...   0.0034
# 3              3  0.0107,0.0108,0.0105,0.0104,0.0109,0.0108,0.01...   0.0015
# 4              4  0.0108,0.0105,0.0104,0.0109,0.0108,0.0102,0.01...   0.0000
# ...          ...                                                ...      ...
# 1891        1891  0.8504,0.7556,0.7311,0.7296,0.7497,0.7507,0.71...   0.6634
# 1892        1892  0.7556,0.7311,0.7296,0.7497,0.7507,0.7188,0.70...   0.6917
# 1893        1893  0.7311,0.7296,0.7497,0.7507,0.7188,0.7021,0.65...   0.7097
# 1894        1894  0.7296,0.7497,0.7507,0.7188,0.7021,0.6589,0.63...   0.6968
# 1895        1895  0.7497,0.7507,0.7188,0.7021,0.6589,0.6344,0.62...   0.7155
#
# [1896 rows x 3 columns]
# --- Isi dari 13.csv ---
#      Unnamed: 0                                  X_test (sequence)  y_test
# 0             0  0.7507,0.7188,0.7021,0.6589,0.6344,0.6235,0.59...  0.7026
# 1             1  0.7188,0.7021,0.6589,0.6344,0.6235,0.5921,0.60...  0.6390
# 2             2  0.7021,0.6589,0.6344,0.6235,0.5921,0.6043,0.59...  0.6242
# 3             3  0.6589,0.6344,0.6235,0.5921,0.6043,0.5959,0.58...  0.6300
# 4             4  0.6344,0.6235,0.5921,0.6043,0.5959,0.5853,0.58...  0.6287
# ..          ...                                                ...     ...
# 469         469  0.4773,0.4749,0.4698,0.4746,0.4593,0.4651,0.46...  0.5311
# 470         470  0.4749,0.4698,0.4746,0.4593,0.4651,0.4681,0.46...  0.5257
# 471         471  0.4698,0.4746,0.4593,0.4651,0.4681,0.4644,0.49...  0.4976
# 472         472  0.4746,0.4593,0.4651,0.4681,0.4644,0.4963,0.46...  0.4979
# 473         473  0.4593,0.4651,0.4681,0.4644,0.4963,0.4613,0.46...  0.4900
#
# [474 rows x 3 columns]
# --- Isi dari 14.csv ---
#    Unnamed: 0         Layer (type)    Output Shape Param #
# 0           0          lstm (LSTM)  (None, 60, 50)  10,400
# 1           1    dropout (Dropout)  (None, 60, 50)       0
# 2           2        lstm_1 (LSTM)      (None, 50)  20,200
# 3           3  dropout_1 (Dropout)      (None, 50)       0
# 4           4        dense (Dense)       (None, 1)      51
# --- Isi dari 15.csv ---
#    Unnamed: 0                  Tanggal  Sebenarnya    Prediksi      Galat  \
# 0           0  2023-07-19T00:00:00.000      203.29  203.109863   0.180137
# 1           1  2023-07-20T00:00:00.000      185.67  203.165421 -17.495421
# 2           2  2023-07-21T00:00:00.000      181.57  196.433304 -14.863304
# 3           3  2023-07-24T00:00:00.000      183.17  187.844315  -4.674315
# 4           4  2023-07-25T00:00:00.000      182.82  181.339890   1.480110
#
#    Galat (%)
# 0   0.088611
# 1  -9.422858
# 2  -8.185991
# 3  -2.551900
# 4   0.809600
# --- Isi dari 16.csv ---
#    Unnamed: 0 Tipe Model  Time Step  Epoch  Epochs Terlatih  Batch Size  \
# 0           0   Baseline         60     50               50          32
#
#      RMSE  MAPE (%)  Durasi (detik)
# 0  6.2864      3.27          179.67
# --- Isi dari 17.csv ---
#    Unnamed: 0         Layer (type)    Output Shape Param #
# 0           0        lstm_4 (LSTM)  (None, 60, 50)  10,400
# 1           1  dropout_4 (Dropout)  (None, 60, 50)       0
# 2           2        lstm_5 (LSTM)      (None, 50)  20,200
# 3           3  dropout_5 (Dropout)      (None, 50)       0
# 4           4      dense_2 (Dense)       (None, 1)      51
# --- Isi dari 18.csv ---
#    Unnamed: 0                  Tanggal  Sebenarnya    Prediksi      Galat  \
# 0           0  2023-07-19T00:00:00.000      203.29  203.544754  -0.254754
# 1           1  2023-07-20T00:00:00.000      185.67  202.560577 -16.890577
# 2           2  2023-07-21T00:00:00.000      181.57  192.865616 -11.295616
# 3           3  2023-07-24T00:00:00.000      183.17  183.876022  -0.706022
# 4           4  2023-07-25T00:00:00.000      182.82  179.981018   2.838982
#
#    Galat (%)
# 0  -0.125316
# 1  -9.097096
# 2  -6.221080
# 3  -0.385446
# 4   1.552884
# --- Isi dari 19.csv ---
#    Unnamed: 0      Tipe Model  Time Step  Epoch  Epochs Terlatih  Batch Size  \
# 0           0  Tuning terbaik         60     75               75          32
#
#      RMSE  MAPE (%)  Durasi (detik)
# 0  5.3872      2.75          261.73
# --- Isi dari 20.csv ---
#     Unnamed: 0 Tipe Model  Time Step  Epoch  Epochs Terlatih  Batch Size  \
# 0            0   Baseline         60     50               50          32
# 1            1     Tuning         30     50               50          32
# 2            2     Tuning         30     50               50          64
# 3            3     Tuning         30     75               73          32
# 4            4     Tuning         30     75               75          64
# 5            5     Tuning         30    100               42          32
# 6            6     Tuning         30    100              100          64
# 7            7     Tuning         60     50               47          64
# 8            8     Tuning         60     75               75          32
# 9            9     Tuning         60     75               51          64
# 10          10     Tuning         60    100               45          32
# 11          11     Tuning         60    100               51          64
#
#       RMSE  MAPE (%)  Durasi (detik)
# 0   6.2864      3.27          179.67
# 1   6.1833      3.18           64.51
# 2   6.7074      3.52           48.32
# 3   5.7182      2.91           89.18
# 4   5.9126      3.05           71.30
# 5   6.6260      3.44           57.96
# 6   5.8597      3.00           92.37
# 7   6.8334      3.65           81.62
# 8   5.3872      2.75          261.73
# 9   6.8538      3.68           96.91
# 10  6.2607      3.27          143.83
# 11  6.8538      3.68           94.20
# --- Isi dari 21.csv ---
#    Unnamed: 0                  Tanggal  Harga yang Diprediksi
# 0           0  2025-06-02T00:00:00.000             144.391663
# 1           1  2025-06-03T00:00:00.000             143.346863
# 2           2  2025-06-04T00:00:00.000             142.725967
# 3           3  2025-06-05T00:00:00.000             142.291245
# 4           4  2025-06-06T00:00:00.000             141.956787
# 5           5  2025-06-09T00:00:00.000             141.688004
# 6           6  2025-06-10T00:00:00.000             141.467133
# 7           7  2025-06-11T00:00:00.000             141.281982
# 8           8  2025-06-12T00:00:00.000             141.122650
# 9           9  2025-06-13T00:00:00.000             140.980713
